# %%
import zipfile
import os
import shutil

# Base paths
base_dir = '/Users/mile/Documents/Projetos/ods4-data-lakehouse-inep'
zip_dir = os.path.join(base_dir, 'data', 'raw')
file_path = os.path.join(base_dir, 'data', 'bronze')

for ano in range(2007, 2025):
    # Check both versions of the filename (with and without trailing underscore)
    zip_name_with_underscore = f'microdados_censo_escolar_{ano}_.zip'
    zip_name_without_underscore = f'microdados_censo_escolar_{ano}.zip'
    
    path_with_underscore = os.path.join(zip_dir, zip_name_with_underscore)
    path_without_underscore = os.path.join(zip_dir, zip_name_without_underscore)
    
    if os.path.exists(path_with_underscore):
        target_zip_path = path_with_underscore
        zip_name = zip_name_with_underscore
    elif os.path.exists(path_without_underscore):
        target_zip_path = path_without_underscore
        zip_name = zip_name_without_underscore
    else:
        print(f'Aviso: Arquivo não encontrado, pulando -> {zip_name_without_underscore} (ou {zip_name_with_underscore})')
        continue

    destino_ano = os.path.join(file_path, f'ano={ano}')
    os.makedirs(destino_ano, exist_ok=True)

    print(f'\n--- Iniciando extração do ano {ano} ---')

    with zipfile.ZipFile(target_zip_path, 'r') as zip_ref:
        filesInZip = zip_ref.namelist()

        for files in filesInZip:
            if 'dados/' in files.lower() and files.lower().endswith('.csv'):
                name_file = os.path.basename(files)
                if not name_file:
                    continue
                final_path = os.path.join(destino_ano, name_file)

                with zip_ref.open(files) as source, open(final_path, 'wb') as target:
                    shutil.copyfileobj(source, target)
                    
                print(f'  -> Salvo: {final_path}')

print('\n✅ Processo de extração de todos os anos concluído!')
# Out:
# --- Iniciando extração do ano 2007 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2007/microdados_ed_basica_2007.csv
#
# --- Iniciando extração do ano 2008 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2008/microdados_ed_basica_2008.csv
#
# --- Iniciando extração do ano 2009 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2009/microdados_ed_basica_2009.csv
#
# --- Iniciando extração do ano 2010 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2010/microdados_ed_basica_2010.csv
#
# --- Iniciando extração do ano 2011 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2011/microdados_ed_basica_2011.csv
#
# --- Iniciando extração do ano 2012 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2012/microdados_ed_basica_2012.csv
#
# --- Iniciando extração do ano 2013 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2013/microdados_ed_basica_2013.csv
#
# --- Iniciando extração do ano 2014 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2014/microdados_ed_basica_2014.csv
#
# --- Iniciando extração do ano 2015 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2015/microdados_ed_basica_2015.csv
#
# --- Iniciando extração do ano 2016 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2016/microdados_ed_basica_2016.csv
#
# --- Iniciando extração do ano 2017 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2017/microdados_ed_basica_2017.csv
#
# --- Iniciando extração do ano 2018 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2018/microdados_ed_basica_2018.csv
#
# --- Iniciando extração do ano 2019 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2019/microdados_ed_basica_2019.csv
#
# --- Iniciando extração do ano 2020 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2020/microdados_ed_basica_2020.CSV
#
# --- Iniciando extração do ano 2021 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2021/microdados_ed_basica_2021.csv
#
# --- Iniciando extração do ano 2022 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2022/microdados_ed_basica_2022.csv
#
# --- Iniciando extração do ano 2023 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2023/microdados_ed_basica_2023.csv
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2023/suplemento_cursos_tecnicos_2023.csv
#
# --- Iniciando extração do ano 2024 ---
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2024/microdados_ed_basica_2024.csv
#   -> Salvo: /Users/mile/Documents/Projetos/ods4-data-lakehouse-inep/data/bronze/ano=2024/suplemento_cursos_tecnicos_2024.csv
#
# ✅ Processo de extração de todos os anos concluído!
